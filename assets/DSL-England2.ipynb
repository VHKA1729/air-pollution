# %%
# import libraries
# %matplotlib inline
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import plotly.express as px
import plotly.graph_objects as go

from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
region = pd.read_csv("regions.csv")

# %%
train.shape, test.shape, region.shape
# Out:
# ((18403, 9), (7886, 8), (9, 2))

# %%
train.head()
# Out:
#    Id     region        date  mortality_rate      O3   PM10  PM25  NO2  \
# 0   1  E12000001  2007-01-02           2.264  42.358  9.021   NaN  NaN
# 1   2  E12000001  2007-01-03           2.030  49.506  5.256   NaN  NaN
# 2   3  E12000001  2007-01-04           1.874  51.101  4.946   NaN  NaN
# 3   4  E12000001  2007-01-05           2.069  47.478  6.823   NaN  NaN
# 4   5  E12000001  2007-01-06           1.913  45.226  7.532   NaN  NaN
#
#        T2M
# 0  278.138
# 1  281.745
# 2  280.523
# 3  280.421
# 4  278.961

# %%
test.head()
# Out:
#       Id     region        date      O3    PM10    PM25     NO2      T2M
# 0  18404  E12000006  2012-05-28  75.980  20.876  19.123   9.713  290.787
# 1  18405  E12000006  2012-05-29  73.084  21.660  17.794   8.417  288.474
# 2  18406  E12000006  2012-05-30  59.350  21.925  17.699  10.878  289.889
# 3  18407  E12000006  2012-05-31  45.991  14.549  11.386  10.302  287.815
# 4  18408  E12000006  2012-06-01  52.210  11.208   9.545   8.598  287.627

# %%
region.head()
# Out:
#         Code                    Region
# 0  E12000001                North East
# 1  E12000002                North West
# 2  E12000003  Yorkshire and The Humber
# 3  E12000004             East Midlands
# 4  E12000005             West Midlands

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18403 entries, 0 to 18402
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              18403 non-null  int64
#  1   region          18403 non-null  object
#  2   date            18403 non-null  object
#  3   mortality_rate  18403 non-null  float64
#  4   O3              18394 non-null  float64
#  5   PM10            18394 non-null  float64
#  6   PM25            15127 non-null  float64
#  7   NO2             11833 non-null  float64
#  8   T2M             18403 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 1.3+ MB

# %%
region
# Out:
#         Code                    Region
# 0  E12000001                North East
# 1  E12000002                North West
# 2  E12000003  Yorkshire and The Humber
# 3  E12000004             East Midlands
# 4  E12000005             West Midlands
# 5  E12000006           East of England
# 6  E12000007                    London
# 7  E12000008                South East
# 8  E12000009                South West

# %%
train1 = train.merge(region, left_on='region', right_on='Code')
test1 = test.merge(region, left_on='region', right_on='Code')

# %%
train1.groupby("region")["Region"].unique()
# Out:
# region
# E12000001                  [North East]
# E12000002                  [North West]
# E12000003    [Yorkshire and The Humber]
# E12000004               [East Midlands]
# E12000005               [West Midlands]
# E12000006             [East of England]
# E12000007                      [London]
# E12000008                  [South East]
# E12000009                  [South West]
# Name: Region, dtype: object

# %%
train1.head()
# Out:
#    Id     region        date  mortality_rate      O3   PM10  PM25  NO2  \
# 0   1  E12000001  2007-01-02           2.264  42.358  9.021   NaN  NaN
# 1   2  E12000001  2007-01-03           2.030  49.506  5.256   NaN  NaN
# 2   3  E12000001  2007-01-04           1.874  51.101  4.946   NaN  NaN
# 3   4  E12000001  2007-01-05           2.069  47.478  6.823   NaN  NaN
# 4   5  E12000001  2007-01-06           1.913  45.226  7.532   NaN  NaN
#
#        T2M       Code      Region
# 0  278.138  E12000001  North East
# 1  281.745  E12000001  North East
# 2  280.523  E12000001  North East
# 3  280.421  E12000001  North East
# 4  278.961  E12000001  North East

# %%
train1.drop("region", axis=1, inplace=True)
test1.drop("region", axis=1, inplace=True)

# %% [markdown]
# #### Converting date to datetime format

# %%
train1["date"] = pd.to_datetime(train1['date'])
test1["date"] = pd.to_datetime(test1['date'])

# %% [markdown]
# #### Missing value check

# %%
train1.isna().sum()
# Out:
# Id                   0
# date                 0
# mortality_rate       0
# O3                   9
# PM10                 9
# PM25              3276
# NO2               6570
# T2M                  0
# Code                 0
# Region               0
# dtype: int64

# %%
test1.isna().sum()
# Out:
# Id        0
# date      0
# O3        0
# PM10      0
# PM25      0
# NO2       0
# T2M       0
# Code      0
# Region    0
# dtype: int64

# %% [markdown]
# ## Univariate analysis ##

# %%
# Visualizing mortality_rate
# plt.figure(1)
plt.subplot(121)
sns.distplot(train['mortality_rate']);

plt.subplot(122)
train['mortality_rate'].plot.box(figsize=(16,5))

plt.show()

# %%
# Visualizing O3
# plt.figure(1)
plt.subplot(121)
O3_1 = train['O3'].dropna()
sns.distplot(O3_1);

plt.subplot(122)
O3_1.plot.box(figsize=(16,5))

plt.show()

# %%
# Visualizing PM10
# plt.figure(1)
plt.subplot(121)
PM10_1 = train['PM10'].dropna()
sns.distplot(PM10_1);

plt.subplot(122)
PM10_1.plot.box(figsize=(16,5))

plt.show()

# %%
# Visualizing PM25
# plt.figure(1)
plt.subplot(121)
PM25_1 = train['PM25'].dropna()
sns.distplot(PM25_1);

plt.subplot(122)
PM25_1.plot.box(figsize=(16,5))

plt.show()

# %%
# Visualizing NO2
# plt.figure(1)
plt.subplot(121)
NO2_1 = train['NO2'].dropna()
sns.distplot(NO2_1);

plt.subplot(122)
NO2_1.plot.box(figsize=(16,5))

plt.show()

# %%
# Visualizing T2M
# plt.figure(1)
plt.subplot(121)
sns.distplot(train['T2M']);

plt.subplot(122)
train['T2M'].plot.box(figsize=(16,5))

plt.show()

# %%
# Visualizing categorical features
# plt.figure(1)
plt.subplot(231)
train['region'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'region')

# %% [markdown]
# # Bivariate analysis - Region Wise

# %% [markdown]
# ### variation with date - time series plot ##

# %% [markdown]
# ### For region 1 - North East

# %%
train_r1 = train1[train1["Region"]=="North East"]
fig1 = px.line(train_r1, x='date', y='mortality_rate')
fig1.show()
# Out:
# <div>
#
#
#             <div id="9b3110b2-9f9c-4eb6-8869-76da3c9efbc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b3110b2-9f9c-4eb6-8869-76da3c9efbc8")) {
#                     Plotly.newPlot(
#                         '9b3110b2-9f9c-4eb6-8869-76da3c9efbc8',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "date=%{x}<br>mortality_rate=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2007-01-02T00:00:00", "2007-01-03T00:00:00", "2007-01-04T00:00:00", "2007-01-05T00:00:00", "2007-01-06T00:00:00", "2007-01-07T00:00:00", "2007-01-08T00:00:00", "2007-01-09T00:00:00", "2007-01-10T00:00:00", "2007-01-11T00:00:00", "2007-01-12T00:00:00", "2007-01-13T00:00:00", "2007-01-14T00:00:00", "2007-01-15T00:00:00", "2007-01-16T00:00:00", "2007-01-17T00:00:00", "2007-01-18T00:00:00", "2007-01-19T00:00:00", "2007-01-20T00:00:00", "2007-01-21T00:00:00", "2007-01-22T00:00:00", "2007-01-23T00:00:00", "2007-01-24T00:00:00", "2007-01-25T00:00:00", "2007-01-26T00:00:00", "2007-01-27T00:00:00", "2007-01-28T00:00:00", "2007-01-29T00:00:00", "2007-01-30T00:00:00", "2007-01-31T00:00:00", "2007-02-01T00:00:00", "2007-02-02T00:00:00", "2007-02-03T00:00:00", "2007-02-04T00:00:00", "2007-02-05T00:00:00", "2007-02-06T00:00:00", "2007-02-07T00:00:00", "2007-02-08T00:00:00", "2007-02-09T00:00:00", "2007-02-10T00:00:00", "2007-02-11T00:00:00", "2007-02-12T00:00:00", "2007-02-13T00:00:00", "2007-02-14T00:00:00", "2007-02-15T00:00:00", "2007-02-16T00:00:00", "2007-02-17T00:00:00", "2007-02-18T00:00:00", "2007-02-19T00:00:00", "2007-02-20T00:00:00", "2007-02-21T00:00:00", "2007-02-22T00:00:00", "2007-02-23T00:00:00", "2007-02-24T00:00:00", "2007-02-25T00:00:00", "2007-02-26T00:00:00", "2007-02-27T00:00:00", "2007-02-28T00:00:00", "2007-03-01T00:00:00", "2007-03-02T00:00:00", "2007-03-03T00:00:00", "2007-03-04T00:00:00", "2007-03-05T00:00:00", "2007-03-06T00:00:00", "2007-03-07T00:00:00", "2007-03-08T00:00:00", "2007-03-09T00:00:00", "2007-03-10T00:00:00", "2007-03-11T00:00:00", "2007-03-12T00:00:00", "2007-03-13T00:00:00", "2007-03-14T00:00:00", "2007-03-15T00:00:00", "2007-03-16T00:00:00", "2007-03-17T00:00:00", "2007-03-18T00:00:00", "2007-03-19T00:00:00", "2007-03-20T00:00:00", "2007-03-21T00:00:00", "2007-03-22T00:00:00", "2007-03-23T00:00:00", "2007-03-24T00:00:00", "2007-03-25T00:00:00", "2007-03-26T00:00:00", "2007-03-27T00:00:00", "2007-03-28T00:00:00", "2007-03-29T00:00:00", "2007-03-30T00:00:00", "2007-03-31T00:00:00", "2007-04-01T00:00:00", "2007-04-02T00:00:00", "2007-04-03T00:00:00", "2007-04-04T00:00:00", "2007-04-05T00:00:00", "2007-04-06T00:00:00", "2007-04-07T00:00:00", "2007-04-08T00:00:00", "2007-04-09T00:00:00", "2007-04-10T00:00:00", "2007-04-11T00:00:00", "2007-04-12T00:00:00", "2007-04-13T00:00:00", "2007-04-14T00:00:00", "2007-04-15T00:00:00", "2007-04-16T00:00:00", "2007-04-17T00:00:00", "2007-04-18T00:00:00", "2007-04-19T00:00:00", "2007-04-20T00:00:00", "2007-04-21T00:00:00", "2007-04-22T00:00:00", "2007-04-23T00:00:00", "2007-04-24T00:00:00", "2007-04-25T00:00:00", "2007-04-26T00:00:00", "2007-04-27T00:00:00", "2007-04-28T00:00:00", "2007-04-29T00:00:00", "2007-04-30T00:00:00", "2007-05-01T00:00:00", "2007-05-02T00:00:00", "2007-05-03T00:00:00", "2007-05-04T00:00:00", "2007-05-05T00:00:00", "2007-05-06T00:00:00", "2007-05-07T00:00:00", "2007-05-08T00:00:00", "2007-05-09T00:00:00", "2007-05-10T00:00:00", "2007-05-11T00:00:00", "2007-05-12T00:00:00", "2007-05-13T00:00:00", "2007-05-14T00:00:00", "2007-05-15T00:00:00", "2007-05-16T00:00:00", "2007-05-17T00:00:00", "2007-05-18T00:00:00", "2007-05-19T00:00:00", "2007-05-20T00:00:00", "2007-05-21T00:00:00", "2007-05-22T00:00:00", "2007-05-23T00:00:00", "2007-05-24T00:00:00", "2007-05-25T00:00:00", "2007-05-26T00:00:00", "2007-05-27T00:00:00", "2007-05-28T00:00:00", "2007-05-29T00:00:00", "2007-05-30T00:00:00", "2007-05-31T00:00:00", "2007-06-01T00:00:00", "2007-06-02T00:00:00", "2007-06-03T00:00:00", "2007-06-04T00:00:00", "2007-06-05T00:00:00", "2007-06-06T00:00:00", "2007-06-07T00:00:00", "2007-06-08T00:00:00", "2007-06-09T00:00:00", "2007-06-10T00:00:00", "2007-06-11T00:00:00", "2007-06-12T00:00:00", "2007-06-13T00:00:0 ...

# %%
fig2 = go.Figure([go.Scatter(x=train_r1['date'], y=train_r1['mortality_rate'])])
#fig2.show()

fig2.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
# Out:
# <div>
#
#
#             <div id="5d6749b5-0447-4a0e-9073-5fe406a43178" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d6749b5-0447-4a0e-9073-5fe406a43178")) {
#                     Plotly.newPlot(
#                         '5d6749b5-0447-4a0e-9073-5fe406a43178',
#                         [{"type": "scatter", "x": ["2007-01-02T00:00:00", "2007-01-03T00:00:00", "2007-01-04T00:00:00", "2007-01-05T00:00:00", "2007-01-06T00:00:00", "2007-01-07T00:00:00", "2007-01-08T00:00:00", "2007-01-09T00:00:00", "2007-01-10T00:00:00", "2007-01-11T00:00:00", "2007-01-12T00:00:00", "2007-01-13T00:00:00", "2007-01-14T00:00:00", "2007-01-15T00:00:00", "2007-01-16T00:00:00", "2007-01-17T00:00:00", "2007-01-18T00:00:00", "2007-01-19T00:00:00", "2007-01-20T00:00:00", "2007-01-21T00:00:00", "2007-01-22T00:00:00", "2007-01-23T00:00:00", "2007-01-24T00:00:00", "2007-01-25T00:00:00", "2007-01-26T00:00:00", "2007-01-27T00:00:00", "2007-01-28T00:00:00", "2007-01-29T00:00:00", "2007-01-30T00:00:00", "2007-01-31T00:00:00", "2007-02-01T00:00:00", "2007-02-02T00:00:00", "2007-02-03T00:00:00", "2007-02-04T00:00:00", "2007-02-05T00:00:00", "2007-02-06T00:00:00", "2007-02-07T00:00:00", "2007-02-08T00:00:00", "2007-02-09T00:00:00", "2007-02-10T00:00:00", "2007-02-11T00:00:00", "2007-02-12T00:00:00", "2007-02-13T00:00:00", "2007-02-14T00:00:00", "2007-02-15T00:00:00", "2007-02-16T00:00:00", "2007-02-17T00:00:00", "2007-02-18T00:00:00", "2007-02-19T00:00:00", "2007-02-20T00:00:00", "2007-02-21T00:00:00", "2007-02-22T00:00:00", "2007-02-23T00:00:00", "2007-02-24T00:00:00", "2007-02-25T00:00:00", "2007-02-26T00:00:00", "2007-02-27T00:00:00", "2007-02-28T00:00:00", "2007-03-01T00:00:00", "2007-03-02T00:00:00", "2007-03-03T00:00:00", "2007-03-04T00:00:00", "2007-03-05T00:00:00", "2007-03-06T00:00:00", "2007-03-07T00:00:00", "2007-03-08T00:00:00", "2007-03-09T00:00:00", "2007-03-10T00:00:00", "2007-03-11T00:00:00", "2007-03-12T00:00:00", "2007-03-13T00:00:00", "2007-03-14T00:00:00", "2007-03-15T00:00:00", "2007-03-16T00:00:00", "2007-03-17T00:00:00", "2007-03-18T00:00:00", "2007-03-19T00:00:00", "2007-03-20T00:00:00", "2007-03-21T00:00:00", "2007-03-22T00:00:00", "2007-03-23T00:00:00", "2007-03-24T00:00:00", "2007-03-25T00:00:00", "2007-03-26T00:00:00", "2007-03-27T00:00:00", "2007-03-28T00:00:00", "2007-03-29T00:00:00", "2007-03-30T00:00:00", "2007-03-31T00:00:00", "2007-04-01T00:00:00", "2007-04-02T00:00:00", "2007-04-03T00:00:00", "2007-04-04T00:00:00", "2007-04-05T00:00:00", "2007-04-06T00:00:00", "2007-04-07T00:00:00", "2007-04-08T00:00:00", "2007-04-09T00:00:00", "2007-04-10T00:00:00", "2007-04-11T00:00:00", "2007-04-12T00:00:00", "2007-04-13T00:00:00", "2007-04-14T00:00:00", "2007-04-15T00:00:00", "2007-04-16T00:00:00", "2007-04-17T00:00:00", "2007-04-18T00:00:00", "2007-04-19T00:00:00", "2007-04-20T00:00:00", "2007-04-21T00:00:00", "2007-04-22T00:00:00", "2007-04-23T00:00:00", "2007-04-24T00:00:00", "2007-04-25T00:00:00", "2007-04-26T00:00:00", "2007-04-27T00:00:00", "2007-04-28T00:00:00", "2007-04-29T00:00:00", "2007-04-30T00:00:00", "2007-05-01T00:00:00", "2007-05-02T00:00:00", "2007-05-03T00:00:00", "2007-05-04T00:00:00", "2007-05-05T00:00:00", "2007-05-06T00:00:00", "2007-05-07T00:00:00", "2007-05-08T00:00:00", "2007-05-09T00:00:00", "2007-05-10T00:00:00", "2007-05-11T00:00:00", "2007-05-12T00:00:00", "2007-05-13T00:00:00", "2007-05-14T00:00:00", "2007-05-15T00:00:00", "2007-05-16T00:00:00", "2007-05-17T00:00:00", "2007-05-18T00:00:00", "2007-05-19T00:00:00", "2007-05-20T00:00:00", "2007-05-21T00:00:00", "2007-05-22T00:00:00", "2007-05-23T00:00:00", "2007-05-24T00:00:00", "2007-05-25T00:00:00", "2007-05-26T00:00:00", "2007-05-27T00:00:00", "2007-05-28T00:00:00", "2007-05-29T00:00:00", "2007-05-30T00:00:00", "2007-05-31T00:00:00", "2007-06-01T00:00:00", "2007-06-02T00:00:00", "2007-06-03T00:00:00", "2007-06-04T00:00:00", "2007-06-05T00:00:00", "2007-06-06T00:00:00", "2007-06-07T00:00:00", "2007-06-08T00:00:00", "2007-06-09T00:00:00", "2007-06-10T00:00:00", "2007-06-11T00:00:00", "2007-06-12T00:00:00", "2007-06-13T00:00:00", "2007-06-14T00:00:00", "2007-06-15T00:00:00", "2007-06-16T00:00:00", "2007-06-17T00:00:00", "2007-06-18T00:00:00", "2007-06-19T00:00:00", "2007-06-20T00:00:00", "2007-06-21T00:00:00", "2007-06-22T00:0 ...

# %%
fig3 = go.Figure([go.Scatter(x=train_r1['date'], y=train_r1["O3"])])
#fig2.show()

fig3.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
# Out:
# <div>
#
#
#             <div id="d24856a6-3fb9-4c35-9bed-fa58110c40db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d24856a6-3fb9-4c35-9bed-fa58110c40db")) {
#                     Plotly.newPlot(
#                         'd24856a6-3fb9-4c35-9bed-fa58110c40db',
#                         [{"type": "scatter", "x": ["2007-01-02T00:00:00", "2007-01-03T00:00:00", "2007-01-04T00:00:00", "2007-01-05T00:00:00", "2007-01-06T00:00:00", "2007-01-07T00:00:00", "2007-01-08T00:00:00", "2007-01-09T00:00:00", "2007-01-10T00:00:00", "2007-01-11T00:00:00", "2007-01-12T00:00:00", "2007-01-13T00:00:00", "2007-01-14T00:00:00", "2007-01-15T00:00:00", "2007-01-16T00:00:00", "2007-01-17T00:00:00", "2007-01-18T00:00:00", "2007-01-19T00:00:00", "2007-01-20T00:00:00", "2007-01-21T00:00:00", "2007-01-22T00:00:00", "2007-01-23T00:00:00", "2007-01-24T00:00:00", "2007-01-25T00:00:00", "2007-01-26T00:00:00", "2007-01-27T00:00:00", "2007-01-28T00:00:00", "2007-01-29T00:00:00", "2007-01-30T00:00:00", "2007-01-31T00:00:00", "2007-02-01T00:00:00", "2007-02-02T00:00:00", "2007-02-03T00:00:00", "2007-02-04T00:00:00", "2007-02-05T00:00:00", "2007-02-06T00:00:00", "2007-02-07T00:00:00", "2007-02-08T00:00:00", "2007-02-09T00:00:00", "2007-02-10T00:00:00", "2007-02-11T00:00:00", "2007-02-12T00:00:00", "2007-02-13T00:00:00", "2007-02-14T00:00:00", "2007-02-15T00:00:00", "2007-02-16T00:00:00", "2007-02-17T00:00:00", "2007-02-18T00:00:00", "2007-02-19T00:00:00", "2007-02-20T00:00:00", "2007-02-21T00:00:00", "2007-02-22T00:00:00", "2007-02-23T00:00:00", "2007-02-24T00:00:00", "2007-02-25T00:00:00", "2007-02-26T00:00:00", "2007-02-27T00:00:00", "2007-02-28T00:00:00", "2007-03-01T00:00:00", "2007-03-02T00:00:00", "2007-03-03T00:00:00", "2007-03-04T00:00:00", "2007-03-05T00:00:00", "2007-03-06T00:00:00", "2007-03-07T00:00:00", "2007-03-08T00:00:00", "2007-03-09T00:00:00", "2007-03-10T00:00:00", "2007-03-11T00:00:00", "2007-03-12T00:00:00", "2007-03-13T00:00:00", "2007-03-14T00:00:00", "2007-03-15T00:00:00", "2007-03-16T00:00:00", "2007-03-17T00:00:00", "2007-03-18T00:00:00", "2007-03-19T00:00:00", "2007-03-20T00:00:00", "2007-03-21T00:00:00", "2007-03-22T00:00:00", "2007-03-23T00:00:00", "2007-03-24T00:00:00", "2007-03-25T00:00:00", "2007-03-26T00:00:00", "2007-03-27T00:00:00", "2007-03-28T00:00:00", "2007-03-29T00:00:00", "2007-03-30T00:00:00", "2007-03-31T00:00:00", "2007-04-01T00:00:00", "2007-04-02T00:00:00", "2007-04-03T00:00:00", "2007-04-04T00:00:00", "2007-04-05T00:00:00", "2007-04-06T00:00:00", "2007-04-07T00:00:00", "2007-04-08T00:00:00", "2007-04-09T00:00:00", "2007-04-10T00:00:00", "2007-04-11T00:00:00", "2007-04-12T00:00:00", "2007-04-13T00:00:00", "2007-04-14T00:00:00", "2007-04-15T00:00:00", "2007-04-16T00:00:00", "2007-04-17T00:00:00", "2007-04-18T00:00:00", "2007-04-19T00:00:00", "2007-04-20T00:00:00", "2007-04-21T00:00:00", "2007-04-22T00:00:00", "2007-04-23T00:00:00", "2007-04-24T00:00:00", "2007-04-25T00:00:00", "2007-04-26T00:00:00", "2007-04-27T00:00:00", "2007-04-28T00:00:00", "2007-04-29T00:00:00", "2007-04-30T00:00:00", "2007-05-01T00:00:00", "2007-05-02T00:00:00", "2007-05-03T00:00:00", "2007-05-04T00:00:00", "2007-05-05T00:00:00", "2007-05-06T00:00:00", "2007-05-07T00:00:00", "2007-05-08T00:00:00", "2007-05-09T00:00:00", "2007-05-10T00:00:00", "2007-05-11T00:00:00", "2007-05-12T00:00:00", "2007-05-13T00:00:00", "2007-05-14T00:00:00", "2007-05-15T00:00:00", "2007-05-16T00:00:00", "2007-05-17T00:00:00", "2007-05-18T00:00:00", "2007-05-19T00:00:00", "2007-05-20T00:00:00", "2007-05-21T00:00:00", "2007-05-22T00:00:00", "2007-05-23T00:00:00", "2007-05-24T00:00:00", "2007-05-25T00:00:00", "2007-05-26T00:00:00", "2007-05-27T00:00:00", "2007-05-28T00:00:00", "2007-05-29T00:00:00", "2007-05-30T00:00:00", "2007-05-31T00:00:00", "2007-06-01T00:00:00", "2007-06-02T00:00:00", "2007-06-03T00:00:00", "2007-06-04T00:00:00", "2007-06-05T00:00:00", "2007-06-06T00:00:00", "2007-06-07T00:00:00", "2007-06-08T00:00:00", "2007-06-09T00:00:00", "2007-06-10T00:00:00", "2007-06-11T00:00:00", "2007-06-12T00:00:00", "2007-06-13T00:00:00", "2007-06-14T00:00:00", "2007-06-15T00:00:00", "2007-06-16T00:00:00", "2007-06-17T00:00:00", "2007-06-18T00:00:00", "2007-06-19T00:00:00", "2007-06-20T00:00:00", "2007-06-21T00:00:00", "2007-06-22T00:0 ...

# %%
fig2 = go.Figure([go.Scatter(x=train_r1['date'], y=train_r1["PM10"])])
#fig2.show()

fig2.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
# Out:
# <div>
#
#
#             <div id="c8c6067d-205b-4314-bbf8-ca8ba88e8f01" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c8c6067d-205b-4314-bbf8-ca8ba88e8f01")) {
#                     Plotly.newPlot(
#                         'c8c6067d-205b-4314-bbf8-ca8ba88e8f01',
#                         [{"type": "scatter", "x": ["2007-01-02T00:00:00", "2007-01-03T00:00:00", "2007-01-04T00:00:00", "2007-01-05T00:00:00", "2007-01-06T00:00:00", "2007-01-07T00:00:00", "2007-01-08T00:00:00", "2007-01-09T00:00:00", "2007-01-10T00:00:00", "2007-01-11T00:00:00", "2007-01-12T00:00:00", "2007-01-13T00:00:00", "2007-01-14T00:00:00", "2007-01-15T00:00:00", "2007-01-16T00:00:00", "2007-01-17T00:00:00", "2007-01-18T00:00:00", "2007-01-19T00:00:00", "2007-01-20T00:00:00", "2007-01-21T00:00:00", "2007-01-22T00:00:00", "2007-01-23T00:00:00", "2007-01-24T00:00:00", "2007-01-25T00:00:00", "2007-01-26T00:00:00", "2007-01-27T00:00:00", "2007-01-28T00:00:00", "2007-01-29T00:00:00", "2007-01-30T00:00:00", "2007-01-31T00:00:00", "2007-02-01T00:00:00", "2007-02-02T00:00:00", "2007-02-03T00:00:00", "2007-02-04T00:00:00", "2007-02-05T00:00:00", "2007-02-06T00:00:00", "2007-02-07T00:00:00", "2007-02-08T00:00:00", "2007-02-09T00:00:00", "2007-02-10T00:00:00", "2007-02-11T00:00:00", "2007-02-12T00:00:00", "2007-02-13T00:00:00", "2007-02-14T00:00:00", "2007-02-15T00:00:00", "2007-02-16T00:00:00", "2007-02-17T00:00:00", "2007-02-18T00:00:00", "2007-02-19T00:00:00", "2007-02-20T00:00:00", "2007-02-21T00:00:00", "2007-02-22T00:00:00", "2007-02-23T00:00:00", "2007-02-24T00:00:00", "2007-02-25T00:00:00", "2007-02-26T00:00:00", "2007-02-27T00:00:00", "2007-02-28T00:00:00", "2007-03-01T00:00:00", "2007-03-02T00:00:00", "2007-03-03T00:00:00", "2007-03-04T00:00:00", "2007-03-05T00:00:00", "2007-03-06T00:00:00", "2007-03-07T00:00:00", "2007-03-08T00:00:00", "2007-03-09T00:00:00", "2007-03-10T00:00:00", "2007-03-11T00:00:00", "2007-03-12T00:00:00", "2007-03-13T00:00:00", "2007-03-14T00:00:00", "2007-03-15T00:00:00", "2007-03-16T00:00:00", "2007-03-17T00:00:00", "2007-03-18T00:00:00", "2007-03-19T00:00:00", "2007-03-20T00:00:00", "2007-03-21T00:00:00", "2007-03-22T00:00:00", "2007-03-23T00:00:00", "2007-03-24T00:00:00", "2007-03-25T00:00:00", "2007-03-26T00:00:00", "2007-03-27T00:00:00", "2007-03-28T00:00:00", "2007-03-29T00:00:00", "2007-03-30T00:00:00", "2007-03-31T00:00:00", "2007-04-01T00:00:00", "2007-04-02T00:00:00", "2007-04-03T00:00:00", "2007-04-04T00:00:00", "2007-04-05T00:00:00", "2007-04-06T00:00:00", "2007-04-07T00:00:00", "2007-04-08T00:00:00", "2007-04-09T00:00:00", "2007-04-10T00:00:00", "2007-04-11T00:00:00", "2007-04-12T00:00:00", "2007-04-13T00:00:00", "2007-04-14T00:00:00", "2007-04-15T00:00:00", "2007-04-16T00:00:00", "2007-04-17T00:00:00", "2007-04-18T00:00:00", "2007-04-19T00:00:00", "2007-04-20T00:00:00", "2007-04-21T00:00:00", "2007-04-22T00:00:00", "2007-04-23T00:00:00", "2007-04-24T00:00:00", "2007-04-25T00:00:00", "2007-04-26T00:00:00", "2007-04-27T00:00:00", "2007-04-28T00:00:00", "2007-04-29T00:00:00", "2007-04-30T00:00:00", "2007-05-01T00:00:00", "2007-05-02T00:00:00", "2007-05-03T00:00:00", "2007-05-04T00:00:00", "2007-05-05T00:00:00", "2007-05-06T00:00:00", "2007-05-07T00:00:00", "2007-05-08T00:00:00", "2007-05-09T00:00:00", "2007-05-10T00:00:00", "2007-05-11T00:00:00", "2007-05-12T00:00:00", "2007-05-13T00:00:00", "2007-05-14T00:00:00", "2007-05-15T00:00:00", "2007-05-16T00:00:00", "2007-05-17T00:00:00", "2007-05-18T00:00:00", "2007-05-19T00:00:00", "2007-05-20T00:00:00", "2007-05-21T00:00:00", "2007-05-22T00:00:00", "2007-05-23T00:00:00", "2007-05-24T00:00:00", "2007-05-25T00:00:00", "2007-05-26T00:00:00", "2007-05-27T00:00:00", "2007-05-28T00:00:00", "2007-05-29T00:00:00", "2007-05-30T00:00:00", "2007-05-31T00:00:00", "2007-06-01T00:00:00", "2007-06-02T00:00:00", "2007-06-03T00:00:00", "2007-06-04T00:00:00", "2007-06-05T00:00:00", "2007-06-06T00:00:00", "2007-06-07T00:00:00", "2007-06-08T00:00:00", "2007-06-09T00:00:00", "2007-06-10T00:00:00", "2007-06-11T00:00:00", "2007-06-12T00:00:00", "2007-06-13T00:00:00", "2007-06-14T00:00:00", "2007-06-15T00:00:00", "2007-06-16T00:00:00", "2007-06-17T00:00:00", "2007-06-18T00:00:00", "2007-06-19T00:00:00", "2007-06-20T00:00:00", "2007-06-21T00:00:00", "2007-06-22T00:0 ...

# %%
fig4 = go.Figure([go.Scatter(x=train_r1['date'], y=train_r1["PM25"])])
#fig2.show()

fig4.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
# Out:
# <div>
#
#
#             <div id="2cacb461-4ccc-4e33-886a-b66d7e5afade" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2cacb461-4ccc-4e33-886a-b66d7e5afade")) {
#                     Plotly.newPlot(
#                         '2cacb461-4ccc-4e33-886a-b66d7e5afade',
#                         [{"type": "scatter", "x": ["2007-01-02T00:00:00", "2007-01-03T00:00:00", "2007-01-04T00:00:00", "2007-01-05T00:00:00", "2007-01-06T00:00:00", "2007-01-07T00:00:00", "2007-01-08T00:00:00", "2007-01-09T00:00:00", "2007-01-10T00:00:00", "2007-01-11T00:00:00", "2007-01-12T00:00:00", "2007-01-13T00:00:00", "2007-01-14T00:00:00", "2007-01-15T00:00:00", "2007-01-16T00:00:00", "2007-01-17T00:00:00", "2007-01-18T00:00:00", "2007-01-19T00:00:00", "2007-01-20T00:00:00", "2007-01-21T00:00:00", "2007-01-22T00:00:00", "2007-01-23T00:00:00", "2007-01-24T00:00:00", "2007-01-25T00:00:00", "2007-01-26T00:00:00", "2007-01-27T00:00:00", "2007-01-28T00:00:00", "2007-01-29T00:00:00", "2007-01-30T00:00:00", "2007-01-31T00:00:00", "2007-02-01T00:00:00", "2007-02-02T00:00:00", "2007-02-03T00:00:00", "2007-02-04T00:00:00", "2007-02-05T00:00:00", "2007-02-06T00:00:00", "2007-02-07T00:00:00", "2007-02-08T00:00:00", "2007-02-09T00:00:00", "2007-02-10T00:00:00", "2007-02-11T00:00:00", "2007-02-12T00:00:00", "2007-02-13T00:00:00", "2007-02-14T00:00:00", "2007-02-15T00:00:00", "2007-02-16T00:00:00", "2007-02-17T00:00:00", "2007-02-18T00:00:00", "2007-02-19T00:00:00", "2007-02-20T00:00:00", "2007-02-21T00:00:00", "2007-02-22T00:00:00", "2007-02-23T00:00:00", "2007-02-24T00:00:00", "2007-02-25T00:00:00", "2007-02-26T00:00:00", "2007-02-27T00:00:00", "2007-02-28T00:00:00", "2007-03-01T00:00:00", "2007-03-02T00:00:00", "2007-03-03T00:00:00", "2007-03-04T00:00:00", "2007-03-05T00:00:00", "2007-03-06T00:00:00", "2007-03-07T00:00:00", "2007-03-08T00:00:00", "2007-03-09T00:00:00", "2007-03-10T00:00:00", "2007-03-11T00:00:00", "2007-03-12T00:00:00", "2007-03-13T00:00:00", "2007-03-14T00:00:00", "2007-03-15T00:00:00", "2007-03-16T00:00:00", "2007-03-17T00:00:00", "2007-03-18T00:00:00", "2007-03-19T00:00:00", "2007-03-20T00:00:00", "2007-03-21T00:00:00", "2007-03-22T00:00:00", "2007-03-23T00:00:00", "2007-03-24T00:00:00", "2007-03-25T00:00:00", "2007-03-26T00:00:00", "2007-03-27T00:00:00", "2007-03-28T00:00:00", "2007-03-29T00:00:00", "2007-03-30T00:00:00", "2007-03-31T00:00:00", "2007-04-01T00:00:00", "2007-04-02T00:00:00", "2007-04-03T00:00:00", "2007-04-04T00:00:00", "2007-04-05T00:00:00", "2007-04-06T00:00:00", "2007-04-07T00:00:00", "2007-04-08T00:00:00", "2007-04-09T00:00:00", "2007-04-10T00:00:00", "2007-04-11T00:00:00", "2007-04-12T00:00:00", "2007-04-13T00:00:00", "2007-04-14T00:00:00", "2007-04-15T00:00:00", "2007-04-16T00:00:00", "2007-04-17T00:00:00", "2007-04-18T00:00:00", "2007-04-19T00:00:00", "2007-04-20T00:00:00", "2007-04-21T00:00:00", "2007-04-22T00:00:00", "2007-04-23T00:00:00", "2007-04-24T00:00:00", "2007-04-25T00:00:00", "2007-04-26T00:00:00", "2007-04-27T00:00:00", "2007-04-28T00:00:00", "2007-04-29T00:00:00", "2007-04-30T00:00:00", "2007-05-01T00:00:00", "2007-05-02T00:00:00", "2007-05-03T00:00:00", "2007-05-04T00:00:00", "2007-05-05T00:00:00", "2007-05-06T00:00:00", "2007-05-07T00:00:00", "2007-05-08T00:00:00", "2007-05-09T00:00:00", "2007-05-10T00:00:00", "2007-05-11T00:00:00", "2007-05-12T00:00:00", "2007-05-13T00:00:00", "2007-05-14T00:00:00", "2007-05-15T00:00:00", "2007-05-16T00:00:00", "2007-05-17T00:00:00", "2007-05-18T00:00:00", "2007-05-19T00:00:00", "2007-05-20T00:00:00", "2007-05-21T00:00:00", "2007-05-22T00:00:00", "2007-05-23T00:00:00", "2007-05-24T00:00:00", "2007-05-25T00:00:00", "2007-05-26T00:00:00", "2007-05-27T00:00:00", "2007-05-28T00:00:00", "2007-05-29T00:00:00", "2007-05-30T00:00:00", "2007-05-31T00:00:00", "2007-06-01T00:00:00", "2007-06-02T00:00:00", "2007-06-03T00:00:00", "2007-06-04T00:00:00", "2007-06-05T00:00:00", "2007-06-06T00:00:00", "2007-06-07T00:00:00", "2007-06-08T00:00:00", "2007-06-09T00:00:00", "2007-06-10T00:00:00", "2007-06-11T00:00:00", "2007-06-12T00:00:00", "2007-06-13T00:00:00", "2007-06-14T00:00:00", "2007-06-15T00:00:00", "2007-06-16T00:00:00", "2007-06-17T00:00:00", "2007-06-18T00:00:00", "2007-06-19T00:00:00", "2007-06-20T00:00:00", "2007-06-21T00:00:00", "2007-06-22T00:0 ...

# %%
fig5 = go.Figure([go.Scatter(x=train_r1['date'], y=train_r1["NO2"])])
#fig2.show()

fig5.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
# Out:
# <div>
#
#
#             <div id="93db22f4-b50f-41d7-b613-259f8a4e96d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93db22f4-b50f-41d7-b613-259f8a4e96d6")) {
#                     Plotly.newPlot(
#                         '93db22f4-b50f-41d7-b613-259f8a4e96d6',
#                         [{"type": "scatter", "x": ["2007-01-02T00:00:00", "2007-01-03T00:00:00", "2007-01-04T00:00:00", "2007-01-05T00:00:00", "2007-01-06T00:00:00", "2007-01-07T00:00:00", "2007-01-08T00:00:00", "2007-01-09T00:00:00", "2007-01-10T00:00:00", "2007-01-11T00:00:00", "2007-01-12T00:00:00", "2007-01-13T00:00:00", "2007-01-14T00:00:00", "2007-01-15T00:00:00", "2007-01-16T00:00:00", "2007-01-17T00:00:00", "2007-01-18T00:00:00", "2007-01-19T00:00:00", "2007-01-20T00:00:00", "2007-01-21T00:00:00", "2007-01-22T00:00:00", "2007-01-23T00:00:00", "2007-01-24T00:00:00", "2007-01-25T00:00:00", "2007-01-26T00:00:00", "2007-01-27T00:00:00", "2007-01-28T00:00:00", "2007-01-29T00:00:00", "2007-01-30T00:00:00", "2007-01-31T00:00:00", "2007-02-01T00:00:00", "2007-02-02T00:00:00", "2007-02-03T00:00:00", "2007-02-04T00:00:00", "2007-02-05T00:00:00", "2007-02-06T00:00:00", "2007-02-07T00:00:00", "2007-02-08T00:00:00", "2007-02-09T00:00:00", "2007-02-10T00:00:00", "2007-02-11T00:00:00", "2007-02-12T00:00:00", "2007-02-13T00:00:00", "2007-02-14T00:00:00", "2007-02-15T00:00:00", "2007-02-16T00:00:00", "2007-02-17T00:00:00", "2007-02-18T00:00:00", "2007-02-19T00:00:00", "2007-02-20T00:00:00", "2007-02-21T00:00:00", "2007-02-22T00:00:00", "2007-02-23T00:00:00", "2007-02-24T00:00:00", "2007-02-25T00:00:00", "2007-02-26T00:00:00", "2007-02-27T00:00:00", "2007-02-28T00:00:00", "2007-03-01T00:00:00", "2007-03-02T00:00:00", "2007-03-03T00:00:00", "2007-03-04T00:00:00", "2007-03-05T00:00:00", "2007-03-06T00:00:00", "2007-03-07T00:00:00", "2007-03-08T00:00:00", "2007-03-09T00:00:00", "2007-03-10T00:00:00", "2007-03-11T00:00:00", "2007-03-12T00:00:00", "2007-03-13T00:00:00", "2007-03-14T00:00:00", "2007-03-15T00:00:00", "2007-03-16T00:00:00", "2007-03-17T00:00:00", "2007-03-18T00:00:00", "2007-03-19T00:00:00", "2007-03-20T00:00:00", "2007-03-21T00:00:00", "2007-03-22T00:00:00", "2007-03-23T00:00:00", "2007-03-24T00:00:00", "2007-03-25T00:00:00", "2007-03-26T00:00:00", "2007-03-27T00:00:00", "2007-03-28T00:00:00", "2007-03-29T00:00:00", "2007-03-30T00:00:00", "2007-03-31T00:00:00", "2007-04-01T00:00:00", "2007-04-02T00:00:00", "2007-04-03T00:00:00", "2007-04-04T00:00:00", "2007-04-05T00:00:00", "2007-04-06T00:00:00", "2007-04-07T00:00:00", "2007-04-08T00:00:00", "2007-04-09T00:00:00", "2007-04-10T00:00:00", "2007-04-11T00:00:00", "2007-04-12T00:00:00", "2007-04-13T00:00:00", "2007-04-14T00:00:00", "2007-04-15T00:00:00", "2007-04-16T00:00:00", "2007-04-17T00:00:00", "2007-04-18T00:00:00", "2007-04-19T00:00:00", "2007-04-20T00:00:00", "2007-04-21T00:00:00", "2007-04-22T00:00:00", "2007-04-23T00:00:00", "2007-04-24T00:00:00", "2007-04-25T00:00:00", "2007-04-26T00:00:00", "2007-04-27T00:00:00", "2007-04-28T00:00:00", "2007-04-29T00:00:00", "2007-04-30T00:00:00", "2007-05-01T00:00:00", "2007-05-02T00:00:00", "2007-05-03T00:00:00", "2007-05-04T00:00:00", "2007-05-05T00:00:00", "2007-05-06T00:00:00", "2007-05-07T00:00:00", "2007-05-08T00:00:00", "2007-05-09T00:00:00", "2007-05-10T00:00:00", "2007-05-11T00:00:00", "2007-05-12T00:00:00", "2007-05-13T00:00:00", "2007-05-14T00:00:00", "2007-05-15T00:00:00", "2007-05-16T00:00:00", "2007-05-17T00:00:00", "2007-05-18T00:00:00", "2007-05-19T00:00:00", "2007-05-20T00:00:00", "2007-05-21T00:00:00", "2007-05-22T00:00:00", "2007-05-23T00:00:00", "2007-05-24T00:00:00", "2007-05-25T00:00:00", "2007-05-26T00:00:00", "2007-05-27T00:00:00", "2007-05-28T00:00:00", "2007-05-29T00:00:00", "2007-05-30T00:00:00", "2007-05-31T00:00:00", "2007-06-01T00:00:00", "2007-06-02T00:00:00", "2007-06-03T00:00:00", "2007-06-04T00:00:00", "2007-06-05T00:00:00", "2007-06-06T00:00:00", "2007-06-07T00:00:00", "2007-06-08T00:00:00", "2007-06-09T00:00:00", "2007-06-10T00:00:00", "2007-06-11T00:00:00", "2007-06-12T00:00:00", "2007-06-13T00:00:00", "2007-06-14T00:00:00", "2007-06-15T00:00:00", "2007-06-16T00:00:00", "2007-06-17T00:00:00", "2007-06-18T00:00:00", "2007-06-19T00:00:00", "2007-06-20T00:00:00", "2007-06-21T00:00:00", "2007-06-22T00:0 ...

# %% [markdown]
# ### scatter plot of PM25 with other varibles ###

# %%
plt.scatter(x=train_r1['mortality_rate'], y=train_r1["PM25"])

# %%
plt.scatter(x=train_r1['PM10'], y=train_r1["PM25"])

# %%
plt.scatter(x=train_r1['O3'], y=train_r1["PM25"])

# %%
train.columns
# Out:
# Index(['Id', 'region', 'date', 'mortality_rate', 'O3', 'PM10', 'PM25', 'NO2',
#        'T2M'],
#       dtype='object')

# %%
plt.scatter(x=train_r1['NO2'], y=train_r1["PM25"])

# %%
plt.scatter(x=train_r1['T2M'], y=train_r1["PM25"])

# %% [markdown]
# ### scatter plot of NO2 with other varibales ###

# %%
train.columns
# Out:
# Index(['Id', 'region', 'date', 'mortality_rate', 'O3', 'PM10', 'PM25', 'NO2',
#        'T2M'],
#       dtype='object')

# %%
plt.scatter(x=train_r1['mortality_rate'], y=train_r1["NO2"])

# %%
plt.scatter(x=train_r1['O3'], y=train_r1["NO2"])

# %%
plt.scatter(x=train_r1['PM10'], y=train_r1["NO2"])

# %%
plt.scatter(x=train_r1['PM25'], y=train_r1["NO2"])

# %%
plt.scatter(x=train_r1['T2M'], y=train_r1["NO2"])

# %% [markdown]
# ## Missing value imputation using MICE

# %% [markdown]
# #### For Region1 - North East

# %%
train_r1.head()
# Out:
#    Id       date  mortality_rate      O3   PM10  PM25  NO2      T2M  \
# 0   1 2007-01-02           2.264  42.358  9.021   NaN  NaN  278.138
# 1   2 2007-01-03           2.030  49.506  5.256   NaN  NaN  281.745
# 2   3 2007-01-04           1.874  51.101  4.946   NaN  NaN  280.523
# 3   4 2007-01-05           2.069  47.478  6.823   NaN  NaN  280.421
# 4   5 2007-01-06           1.913  45.226  7.532   NaN  NaN  278.961
#
#         Code      Region
# 0  E12000001  North East
# 1  E12000001  North East
# 2  E12000001  North East
# 3  E12000001  North East
# 4  E12000001  North East

# %%
train_r1.isna().sum()
# Out:
# Id                  0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64

# %%
from impyute.imputation.cs import mice

# start the MICE training
train_r1_imp=mice(train_r1.drop(["Id", "date", "Code", "Region"], axis = 1).values)

# %%
train_r1_imp = pd.DataFrame(train_r1_imp, columns = ["mortality_rate", "O3", "PM10", "PM25","NO2","T2M"])

# %%
train_r1_imp.isna().sum()
# Out:
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# dtype: int64

# %%
# Visualizing NO2
# plt.figure(1)
plt.subplot(121)
NO2_1 = train_r1_imp['NO2'].dropna()
sns.distplot(NO2_1);

plt.subplot(122)
NO2_1.plot.box(figsize=(16,5))

plt.show()


plt.subplot(121)
NO2_1 = train_r1['NO2'].dropna()
sns.distplot(NO2_1);

plt.subplot(122)
NO2_1.plot.box(figsize=(16,5))

plt.show()

# %%
plt.scatter(x=train_r1_imp['O3'], y=train_r1_imp["NO2"])
plt.scatter(x=train_r1['O3'], y=train_r1["NO2"])

# %%
plt.scatter(x=train_r1_imp['PM10'], y=train_r1_imp["NO2"])
plt.scatter(x=train_r1['PM10'], y=train_r1["NO2"])

# %%
# Visualizing NO2
# plt.figure(1)
plt.subplot(121)
NO2_1_imp = train_r1_imp['PM25'].dropna()
NO2_1 = train_r1['PM25'].dropna()
#sns.distplot(NO2_1_imp)
#sns.distplot(NO2_1)

sns.distplot(NO2_1_imp, hist=False, rug=True)
sns.distplot(NO2_1, hist=False, rug=True)

# %%
plt.scatter(x=train_r1_imp['PM10'], y=train_r1_imp["PM25"])
plt.scatter(x=train_r1['PM10'], y=train_r1["PM25"])

# %%
train_r1_imp['PM25'].describe(), train_r1['PM25'].describe()
# Out:
# (count    2191.000000
#  mean        5.205221
#  std         4.763198
#  min        -0.633236
#  25%         2.333000
#  50%         3.632598
#  75%         6.158707
#  max        41.255000
#  Name: PM25, dtype: float64,
#  count    1827.000000
#  mean        5.368816
#  std         4.773007
#  min         0.904000
#  25%         2.451500
#  50%         3.802000
#  75%         6.269000
#  max        41.255000
#  Name: PM25, dtype: float64)

# %%
## changing negative values to min value
train_r1_imp['PM25'] = np.where(train_r1_imp['PM25']<=0, 0.904000, train_r1_imp['PM25'] )

# %%
train_r1_imp['NO2'].describe(), train_r1['NO2'].describe()
# Out:
# (count    2191.000000
#  mean        6.164380
#  std         4.375788
#  min        -2.754285
#  25%         3.228438
#  50%         4.988000
#  75%         7.734662
#  max        34.990000
#  Name: NO2, dtype: float64,
#  count    1461.000000
#  mean        6.353291
#  std         4.572821
#  min         1.104000
#  25%         3.172000
#  50%         4.988000
#  75%         7.971000
#  max        34.990000
#  Name: NO2, dtype: float64)

# %%
## changing negative values to min value
train_r1_imp['NO2'] = np.where(train_r1_imp['NO2']<=0, 1.104000, train_r1_imp['NO2'] )

# %% [markdown]
# #### Since we are getting good enough results region wise we can impute PM25 and NO2 on the basis of regions

# %% [markdown]
# ### Region wise imputation

# %%
regions = list(region["Region"].values)
train_imp = pd.DataFrame()

for reg in regions:
    
    train_r = train1[train1["Region"] == reg].reset_index(drop=True)
    train_r_imp = mice(train_r.drop(["Id", "date", "Code", "Region", "region"], axis = 1).values)
    train_r_imp = pd.DataFrame(train_r_imp, columns = ["mortality_rate", "O3", "PM10", "PM25","NO2","T2M"])
    
    ## changing negative values to min value
    train_r_imp['PM25'] = np.where(train_r_imp['PM25']<=0, min(train_r['PM25']), train_r_imp['PM25'] )
    
    ## changing negative values to min value
    train_r_imp['NO2'] = np.where(train_r_imp['NO2']<=0, min(train_r['NO2']), train_r_imp['NO2'] )
    
    print("\n\n")
    print("train_r = before", train_r.isna().sum())
    
    train_r['PM25'] = train_r_imp['PM25']
    train_r['NO2'] = train_r_imp['NO2']
    train_r['O3'] = train_r_imp['O3']
    train_r['PM10'] = train_r_imp['PM10']
    
    print("train_r_imp = \n", train_r_imp.isna().sum())
    print("train_r = \n", train_r.isna().sum())
    print("----------------------------------------")
    
    train_imp = train_imp.append(train_r)
    
print("train_imp = ", train_imp.isna().sum())
# Out:
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate     0
# O3                 0
# PM10               0
# PM25              14
# NO2                8
# T2M                0
# dtype: int64
# train_r =
#  Id                 0
# region             0
# date               0
# mortality_rate     0
# O3                 0
# PM10               0
# PM25              14
# NO2                8
# T2M                0
# Code               0
# Region             0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              5
# NO2               3
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              5
# NO2               3
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               4
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               4
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               2
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               2
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               1
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               1
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              1
# NO2               1
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              1
# NO2               1
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
#
#
#
# train_r = before Id                  0
# region              0
# date                0
# mortality_rate      0
# O3                  1
# PM10                1
# PM25              364
# NO2               730
# T2M                 0
# Code                0
# Region              0
# dtype: int64
# train_r_imp =
#  mortality_rate    0
# O3                0
# PM10              0
# PM25              7
# NO2               0
# T2M               0
# dtype: int64
# train_r =
#  Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              7
# NO2               0
# T2M               0
# Code              0
# Region            0
# dtype: int64
# ----------------------------------------
# train_imp =  Id                 0
# region             0
# date               0
# mortality_rate     0
# O3                 0
# PM10               0
# PM25              27
# NO2               19
# T2M                0
# Code               0
# Region             0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
#train_imp

# %%
temp_r_imp = mice(train_imp.drop(["Id", "date", "Code", "Region", "region"], axis = 1).values)
temp_r_imp = pd.DataFrame(temp_r_imp, columns = ["mortality_rate", "O3", "PM10", "PM25","NO2","T2M"])

train_r_imp_full = train_imp.copy()
train_r_imp_full["NO2"] = temp_r_imp["NO2"]
train_r_imp_full["PM25"] = temp_r_imp["PM25"]
train_r_imp_full["O3"] = temp_r_imp["O3"]
train_r_imp_full["PM10"] = temp_r_imp["PM10"]

train_r_imp_full.isna().sum()  #### FINAL DATAFRAME WITH IMPUTED VALUES REGION WISE
# Out:
# Id                0
# region            0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# Code              0
# Region            0
# dtype: int64

# %%
train_r_imp_full.shape, train1.shape
# Out:
# ((18403, 11), (18403, 10))

# %%
train_r_imp_full.head(50)
# Out:
#     Id     region        date  mortality_rate      O3    PM10       PM25  \
# 0    1  E12000001  2007-01-02           2.264  42.358   9.021   3.985224
# 1    2  E12000001  2007-01-03           2.030  49.506   5.256   1.321535
# 2    3  E12000001  2007-01-04           1.874  51.101   4.946   1.231309
# 3    4  E12000001  2007-01-05           2.069  47.478   6.823   2.462306
# 4    5  E12000001  2007-01-06           1.913  45.226   7.532   3.136436
# 5    6  E12000001  2007-01-07           1.756  53.226   5.607   1.754363
# 6    7  E12000001  2007-01-08           1.756  48.177   4.674   1.167923
# 7    8  E12000001  2007-01-09           2.147  56.917   5.979   1.697248
# 8    9  E12000001  2007-01-10           2.186  45.757   3.433   0.012028
# 9   10  E12000001  2007-01-11           1.249  56.388   6.159   2.528594
# 10  11  E12000001  2007-01-12           2.342  56.014   5.962   1.542021
# 11  12  E12000001  2007-01-13           1.444  55.656   5.122   1.634615
# 12  13  E12000001  2007-01-14           1.678  54.312   4.990   1.416069
# 13  14  E12000001  2007-01-15           2.186  56.654   5.590   1.413702
# 14  15  E12000001  2007-01-16           1.795  33.107   7.525   3.359535
# 15  16  E12000001  2007-01-17           1.678  50.589   5.812   2.059115
# 16  17  E12000001  2007-01-18           2.576  45.819   3.722   0.053593
# 17  18  E12000001  2007-01-19           2.030  49.809   8.244   3.488274
# 18  19  E12000001  2007-01-20           1.756  49.056   6.767   2.685088
# 19  20  E12000001  2007-01-21           1.834  47.730   3.846   0.608968
# 20  21  E12000001  2007-01-22           1.834  48.284   3.341   0.252612
# 21  22  E12000001  2007-01-23           1.756  42.107   2.798   0.021703
# 22  23  E12000001  2007-01-24           1.678  52.358   3.155   0.198965
# 23  24  E12000001  2007-01-25           2.186  41.495   4.348   0.788018
# 24  25  E12000001  2007-01-26           1.327  46.715   5.215   1.925707
# 25  26  E12000001  2007-01-27           1.834  48.000   4.707   1.152485
# 26  27  E12000001  2007-01-28           1.366  54.158   2.884   0.097877
# 27  28  E12000001  2007-01-29           1.913  47.568   6.490   2.342529
# 28  29  E12000001  2007-01-30           1.834  49.412   6.048   2.134079
# 29  30  E12000001  2007-01-31           2.147  49.603   4.470   0.663567
# 30  31  E12000001  2007-02-01           1.600  39.469   7.329   3.206329
# 31  32  E12000001  2007-02-02           1.678  43.624   8.418   3.948998
# 32  33  E12000001  2007-02-03           1.600  38.709   5.702   2.168715
# 33  34  E12000001  2007-02-04           1.678  34.037  15.420   9.131110
# 34  35  E12000001  2007-02-05           1.639  38.911   7.673   3.597952
# 35  36  E12000001  2007-02-06           1.522  36.650   9.351   4.947301
# 36  37  E12000001  2007-02-07           1.210  37.980   4.874   1.945628
# 37  38  E12000001  2007-02-08           1.756  33.293   7.399   3.366047
# 38  39  E12000001  2007-02-09           1.991  35.499  13.971   7.884967
# 39  40  E12000001  2007-02-10           2.342  27.243   7.243   2.824974
# 40  41  E12000001  2007-02-11           1.991  36.894   7.311   3.014847
# 41  42  E12000001  2007-02-12           2.342  38.699   5.839   1.681460
# 42  43  E12000001  2007-02-13           1.834  44.007   7.177   2.968887
# 43  44  E12000001  2007-02-14           1.795  44.311   8.286   3.794027
# 44  45  E12000001  2007-02-15           1.795  45.565  13.240   7.287492
# 45  46  E12000001  2007-02-16           2.303  30.266   9.137   4.094652
# 46  47  E12000001  2007-02-17           1.834  32.182   8.656   4.119102
# 47  48  E12000001  2007-02-18           2.537  42.506  11.195   5.391994
# 48  49  E12000001  2007-02-19           1.795  17.991  21.118  13.168688
# 49  50  E12000001  2007-02-20           1.756  36.770  10.620   5.491670
#
#           NO2      T2M       Code      Region
# 0    7.768462  278.138  E12000001  North East
# 1    4.416754  281.745  E12000001  North East
# 2    4.261085  280.523  E12000001  North East
# 3    5.622606  280.421  E12000001  North East
# 4    6.550947  278.961  E12000001  North East
# 5    3.989717  281.504  E12000001  North East
# 6    4.824377  279.519  E12000001  North East
# 7    3.458943  281.866  E12000001  North East
# 8    5.005039  278.044  E12000001  North East
# 9    3.905907  280.358  E12000001  North East
# 10   3.555292  282.104  E12000001  North East
# 11   3.521456  280.847  E12000001  North East
# 12   4.005851  279.163  E12000001  North East
# 13   3.528104  280.905  E12000001  North East
# 14   8.975918  276.678  E12000001  North East
# 15   5.159711  278.028  E12000001  North East
# 16   4.987891  278.681  E12000001  North East
# 17   5.760851  280.647  E12000001  North East
# 18   5.690323  278.567  E12000001  North East
# 19   5.289365  275.684  E12000001  North East
# 20   5.077184  275.259  E12000001  North East
# 21   6.333878  272.845  E12000001  North East
# 22   4.284483  275.514  E12000001  North East
# 23   6.787517  274.234  E12000001  North East
# 24   5.623680  277.705  E12000001  North East
# 25   5.005163  278.780  E12000001  North East
# 26   2.880593  280.840  E12000001  North East
# 27   5.512698  280.227  E12000001  North East
# 28   5.546544  277.497  E12000001  North East
# 29   4.030958  282.047  E12000001  North East
# 30   6.958301  281.423  E12000001  North East
# 31   7.102692  279.311  E12000001  North East
# 32   7.436838  276.103  E12000001  North East
# 33  12.192513  275.448  E12000001  North East
# 34   8.555162  274.143  E12000001  North East
# 35   9.941550  272.302  E12000001  North East
# 36   7.855318  272.776  E12000001  North East
# 37   9.455494  273.698  E12000001  North East
# 38  11.656370  273.945  E12000001  North East
# 39  10.063781  275.422  E12000001  North East
# 40   8.112282  277.493  E12000001  North East
# 41   7.186017  277.715  E12000001  North East
# 42   6.771937  278.106  E12000001  North East
# 43   7.187265  277.976  E12000001  North East
# 44   8.537825  280.167  E12000001  North East
# 45   9.545352  279.535  E12000001  North East
# 46   9.338868  277.949  E12000001  North East
# 47   9.010284  275.991  E12000001  North East
# 48  16.460874  278.860  E12000001  North East
# 49   8.874458  280.551  E12000001  North East

# %%
train_r_imp_full['NO2'].describe(), train1['NO2'].describe()
train_r_imp_full['PM25'].describe(), train1['PM25'].describe()
# Out:
# (count    18403.000000
#  mean         5.161193
#  std          4.759401
#  min         -1.010948
#  25%          2.272000
#  50%          3.572000
#  75%          6.127000
#  max         41.255000
#  Name: PM25, dtype: float64,
#  count    15127.000000
#  mean         7.498714
#  std          5.758357
#  min          0.904000
#  25%          3.624000
#  50%          5.636000
#  75%          9.326500
#  max         45.846000
#  Name: PM25, dtype: float64)

# %%
plt.subplot(121)
NO2_1= train1['PM25'].dropna()
NO2_1_imp  = train_r_imp_full['PM25'].dropna()
#sns.distplot(NO2_1_imp)
#sns.distplot(NO2_1)

sns.distplot(NO2_1_imp, hist=False, rug=True)
sns.distplot(NO2_1, hist=False, rug=True)

# %% [markdown]
# Region wise imputation is fine but at an overall level it does not suits well..

# %% [markdown]
# ### Impution on full data - MICE

# %%
# start the MICE training
temp_imp = mice(train1.drop(["Id", "date", "Code", "Region"], axis = 1).values)
temp_imp = pd.DataFrame(temp_imp, columns = ["mortality_rate", "O3", "PM10", "PM25","NO2","T2M"])

train_full_imp = train1.copy()
train_full_imp["NO2"] = temp_imp["NO2"]
train_full_imp["PM25"] = temp_imp["PM25"]
train_full_imp["O3"] = temp_imp["O3"]
train_full_imp["PM10"] = temp_imp["PM10"]

# %%
train_full_imp.isna().sum() ### FINAL DATAFRAME WITH IMPUTATION ON FULL DATA
# Out:
# Id                0
# date              0
# mortality_rate    0
# O3                0
# PM10              0
# PM25              0
# NO2               0
# T2M               0
# Code              0
# Region            0
# dtype: int64

# %%
plt.subplot(121)
NO2_1= train1['PM25'].dropna()
NO2_1_imp  = train_full_imp['PM25'].dropna()
#sns.distplot(NO2_1_imp)
#sns.distplot(NO2_1)

sns.distplot(NO2_1_imp, hist=False, rug=True)
sns.distplot(NO2_1, hist=False, rug=True)
